# %% [markdown]
# # 📌 Fase 1. Business Understanding

# %% [markdown]
# ## 🎯 1. Objective

# %% [markdown]
# El objetivo de este proyecto es **desarrollar un modelo predictivo** que permita determinar el **tipo de diabetes en pacientes** (según el código CIE-10, variable `COD_DIAG`) a partir de características clínicas clave, específicamente:
#
# - **Edad del paciente** (`EDAD_PACIENTE`)
# - **Dosaje de glucosa en sangre, cuantitativo** (`RESULTADO_1`)
# - **Dosaje de colesterol total en sangre** (`RESULTADO_2`)

# %% [markdown]
# # 📌 Fase 2. Data Understanding

# %% [markdown]
# ## 📥 2. Data collection

# %%
import pandas as pd
import numpy as np


data = pd.read_csv("data_corregida.csv", 
                    encoding='utf-8',      # o 'latin-1' si hay caracteres especiales
                    sep=',',               # separador (por defecto es coma)
                    header=0,              # fila que contiene los nombres de columnas
                    index_col=None)        # si quieres usar una columna como índice

# %%
# Resumen general
data.info()
print('data.columns:',data.columns)
print('data.shape:',data.shape)
data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509716 entries, 0 to 509715
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   FECHA_CORTE             509716 non-null  int64
#  1   DEPARTAMENTO            509716 non-null  object
#  2   PROVINCIA               509716 non-null  object
#  3   DISTRITO                509716 non-null  object
#  4   UBIGEO                  509716 non-null  int64
#  5   RED                     509716 non-null  object
#  6   IPRESS                  509716 non-null  object
#  7   ID_PACIENTE             509716 non-null  object
#  8   EDAD_PACIENTE           509716 non-null  int64
#  9   SEXO_PACIENTE           509716 non-null  object
#  10  EDAD_MEDICO             509716 non-null  int64
#  11  ID_MEDICO               509716 non-null  object
#  12  COD_DIAG                509716 non-null  object
#  13  DIAGNOSTICO             509716 non-null  object
#  14  AREA_HOSPITALARIA       509716 non-null  object
#  15  SERVICIO_HOSPITALARIO   509716 non-null  object
#  16  ACTIVIDAD_HOSPITALARIA  509716 non-null  object
#  17  FECHA_MUESTRA           509716 non-null  int64
#  18  FEC_RESULTADO_1         509716 non-null  int64
#  19  PROCEDIMIENTO_1         509716 non-null  object
#  20  RESULTADO_1             509716 non-null  float64
#  21  UNIDADES_1              509716 non-null  object
#  22  FEC_RESULTADO_2         509716 non-null  int64
#  23  PROCEDIMIENTO_2         509716 non-null  object
#  24  RESULTADO_2             509716 non-null  float64
#  25  UNIDADES_2              509716 non-null  object
# dtypes: float64(2), int64(7), object(17)
# memory usage: 101.1+ MB
# data.columns: Index(['FECHA_CORTE', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'UBIGEO', 'RED',
#        'IPRESS', 'ID_PACIENTE', 'EDAD_PACIENTE', 'SEXO_PACIENTE',
#        'EDAD_MEDICO', 'ID_MEDICO', 'COD_DIAG', 'DIAGNOSTICO',
#        'AREA_HOSPITALARIA', 'SERVICIO_HOSPITALARIO', 'ACTIVIDAD_HOSPITALARIA',
#        'FECHA_MUESTRA', 'FEC_RESULTADO_1', 'PROCEDIMIENTO_1', 'RESULTADO_1',
#        'UNIDADES_1', 'FEC_RESULTADO_2', 'PROCEDIMIENTO_2', 'RESULTADO_2',
#        'UNIDADES_2'],
#       dtype='object')
# data.shape: (509716, 26)
#    FECHA_CORTE DEPARTAMENTO         PROVINCIA      DISTRITO  UBIGEO  \
# 0     20240531      UCAYALI  CORONEL PORTILLO      MANANTAY  250107
# 1     20240531      UCAYALI  CORONEL PORTILLO   YARINACOCHA  250105
# 2     20240531        TACNA             TACNA        CALANA  230103
# 3     20240531        TACNA             TACNA         TACNA  230101
# 4     20240531   SAN MARTIN          HUALLAGA       SAPOSOA  220401
# 5     20240531  LA LIBERTAD          TRUJILLO  LA ESPERANZA  130105
# 6     20240531  LA LIBERTAD          TRUJILLO  LA ESPERANZA  130105
# 7     20240531         LIMA              LIMA    MIRAFLORES  150122
# 8     20240531      HUANUCO           HUANUCO      AMARILIS  100102
# 9     20240531   SAN MARTIN          HUALLAGA       SAPOSOA  220401
#
#                              RED                               IPRESS  \
# 0        RED ASISTENCIAL UCAYALI                       CAP I MANANTAY
# 1        RED ASISTENCIAL UCAYALI                         P.M. ALAMEDA
# 2          RED ASISTENCIAL TACNA         H.III DANIEL ALCIDES CARRION
# 3          RED ASISTENCIAL TACNA  CAP II OSCAR FERNANDEZ DAVILA VELEZ
# 4  MICRORED ASISTENCIAL TARAPOTO                         P.M. SAPOSOA
# 5    RED ASISTENCIAL LA LIBERTAD                     H.I LA ESPERANZA
# 6    RED ASISTENCIAL LA LIBERTAD                     H.I LA ESPERANZA
# 7     RED ASISTENCIAL REBAGLIATI                 H.III SUAREZ-ANGAMOS
# 8        RED ASISTENCIAL HUANUCO                         H.II HUANUCO
# 9  MICRORED ASISTENCIAL TARAPOTO                         P.M. SAPOSOA
#
#                             ID_PACIENTE  EDAD_PACIENTE SEXO_PACIENTE  ...  \
# 0  eJwzNDAwtDC0NDMxNzAyMzWxMAQAHqoDcA==             51     MASCULINO  ...
# 1  eJwzNDAwMjAxNTUxsbQ0NTAzMgUAHnQDbg==             48      FEMENINO  ...
# 2      eJwzNDCwMLOwMDKztDQHsszNAB+JA4w=             67     MASCULINO  ...
# 3  eJwzNDCwNDU3Mja1MDUyMTCxMAEAHukDdA==             67     MASCULINO  ...
# 4      eJwzNDA0szQCQgMDM2NLcxMTAB8CA3k=             59     MASCULINO  ...
# 5  eJwzNLY0tDC1sDQ1NDezNDa0MAEAH8cDiQ==             55     MASCULINO  ...
# 6  eJwzNLY0NjM3NzE2MDE1MTQxNQMAH1MDeQ==             67     MASCULINO  ...
# 7  eJwzNLY0tjQ1NzYwNrU0sLA0MwQAH4gDgg==             73      FEMENINO  ...
# 8  eJwzNDU0NzA0MDc0tzQ2MjM0MgQAHqEDZw==             58      FEMENINO  ...
# 9  eJwzMrUwMjYxsjA3sTA0MDYyMAEAHzcDcA==             20      FEMENINO  ...
#
#          ACTIVIDAD_HOSPITALARIA FECHA_MUESTRA FEC_RESULTADO_1  \
# 0  ATENCION  MEDICA AMBULATORIA      20200102        20200111
# 1  ATENCION  MEDICA AMBULATORIA      20200102        20200111
# 2  ATENCION  MEDICA AMBULATORIA      20200102        20200102
# 3  ATENCION  MEDICA AMBULATORIA      20200102        20200102
# 4  ATENCION  MEDICA AMBULATORIA      20200102        20200102
# 5  ATENCION  MEDICA AMBULATORIA      20200102        20200102
# 6  ATENCION  MEDICA AMBULATORIA      20200102        20200102
# 7  ATENCION  MEDICA AMBULATORIA      20200102        20200102
# 8  ATENCION  MEDICA AMBULATORIA      20200102        20200106
# 9  ATENCION  MEDICA AMBULATORIA      20200102        20200102
#
#                                      PROCEDIMIENTO_1 RESULTADO_1 UNIDADES_1  \
# 0  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       217.0      mg/dL
# 1  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       192.0      mg/dL
# 2  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       203.0      mg/dL
# 3  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       207.0      mg/dL
# 4  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       155.0      mg/dL
# 5  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       130.0      mg/dL
# 6  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       221.0      mg/dL
# 7  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       152.0      mg/dL
# 8  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       194.0      mg/dL
# 9  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       126.0      mg/dL
#
#   FEC_RESULTADO_2                                    PROCEDIMIENTO_2  \
# 0        20200111  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 1        20200111  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 2        20200102  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 3        20200102  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 4        20200102  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 5        20200102  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 6        20200102  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 7        20200102  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 8        20200106  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 9        20200102  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
#
#    RESULTADO_2 UNIDADES_2
# 0        258.0      mg/dL
# 1        171.0      mg/dL
# 2         78.0      mg/dL
# 3        113.0      mg/dL
# 4         78.0      mg/dL
# 5        149.0      mg/dL
# 6        328.0      mg/dL
# 7         83.0      mg/dL
# 8        221.0      mg/dL
# 9         71.0      mg/dL
#
# [10 rows x 26 columns]

# %% [markdown]
# ## 📊 3. Descriptive analysis

# %% [markdown]
# ### 3.1 Análisis descriptivo

# %%
#Resumen estadístico de todas las variables (describe()).
data.describe(include="all").T # incluye categóricas y numéricas
# Out:
#                            count  unique  \
# FECHA_CORTE             509716.0     NaN
# DEPARTAMENTO              509716      25
# PROVINCIA                 509716     111
# DISTRITO                  509716     227
# UBIGEO                  509716.0     NaN
# RED                       509716      30
# IPRESS                    509716     272
# ID_PACIENTE               509716  260725
# EDAD_PACIENTE           509716.0     NaN
# SEXO_PACIENTE             509716       2
# EDAD_MEDICO             509716.0     NaN
# ID_MEDICO                 509716    5290
# COD_DIAG                  509716      57
# DIAGNOSTICO               509716      57
# AREA_HOSPITALARIA         509716       1
# SERVICIO_HOSPITALARIO     509716      45
# ACTIVIDAD_HOSPITALARIA    509716      11
# FECHA_MUESTRA           509716.0     NaN
# FEC_RESULTADO_1         509716.0     NaN
# PROCEDIMIENTO_1           509716       1
# RESULTADO_1             509716.0     NaN
# UNIDADES_1                509716       2
# FEC_RESULTADO_2         509716.0     NaN
# PROCEDIMIENTO_2           509716       1
# RESULTADO_2             509716.0     NaN
# UNIDADES_2                509716       2
#
#                                                                       top  \
# FECHA_CORTE                                                           NaN
# DEPARTAMENTO                                                         LIMA
# PROVINCIA                                                            LIMA
# DISTRITO                                                             LIMA
# UBIGEO                                                                NaN
# RED                                            RED ASISTENCIAL REBAGLIATI
# IPRESS                                 H.III HOSPITAL DE EMERGENCIAS GRAU
# ID_PACIENTE                          eJwzNDMwsjC2MDQzMTE1NjAwMgUAHuQDaw==
# EDAD_PACIENTE                                                         NaN
# SEXO_PACIENTE                                                    FEMENINO
# EDAD_MEDICO                                                           NaN
# ID_MEDICO                            eJwzNDA1NTWwsDAwNDEwsDQ3MwEAHrkDcA==
# COD_DIAG                                                            E11.9
# DIAGNOSTICO             DIABETES MELLITUS TIPO 2, SIN MENCION DE COMPL...
# AREA_HOSPITALARIA                                        CONSULTA EXTERNA
# SERVICIO_HOSPITALARIO                                    MEDICINA GENERAL
# ACTIVIDAD_HOSPITALARIA                       ATENCION  MEDICA AMBULATORIA
# FECHA_MUESTRA                                                         NaN
# FEC_RESULTADO_1                                                       NaN
# PROCEDIMIENTO_1         DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...
# RESULTADO_1                                                           NaN
# UNIDADES_1                                                          mg/dL
# FEC_RESULTADO_2                                                       NaN
# PROCEDIMIENTO_2         DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# RESULTADO_2                                                           NaN
# UNIDADES_2                                                          mg/dL
#
#                           freq             mean           std         min  \
# FECHA_CORTE                NaN       20240531.0           0.0  20240531.0
# DEPARTAMENTO            180751              NaN           NaN         NaN
# PROVINCIA               170963              NaN           NaN         NaN
# DISTRITO                 39651              NaN           NaN         NaN
# UBIGEO                     NaN    130985.651304   55220.28167     10101.0
# RED                      75651              NaN           NaN         NaN
# IPRESS                   21922              NaN           NaN         NaN
# ID_PACIENTE                 21              NaN           NaN         NaN
# EDAD_PACIENTE              NaN        61.865916     13.336874         0.0
# SEXO_PACIENTE           297424              NaN           NaN         NaN
# EDAD_MEDICO                NaN        46.254889     11.434643        23.0
# ID_MEDICO                 4934              NaN           NaN         NaN
# COD_DIAG                340278              NaN           NaN         NaN
# DIAGNOSTICO             340278              NaN           NaN         NaN
# AREA_HOSPITALARIA       509716              NaN           NaN         NaN
# SERVICIO_HOSPITALARIO   235494              NaN           NaN         NaN
# ACTIVIDAD_HOSPITALARIA  507211              NaN           NaN         NaN
# FECHA_MUESTRA              NaN  20223288.076399  11218.907109  20200102.0
# FEC_RESULTADO_1            NaN  20223305.821787  11218.581031  20200102.0
# PROCEDIMIENTO_1         509716              NaN           NaN         NaN
# RESULTADO_1                NaN       190.599437     51.550477         0.0
# UNIDADES_1              503955              NaN           NaN         NaN
# FEC_RESULTADO_2            NaN   20223306.52915  11219.211046  20200102.0
# PROCEDIMIENTO_2         509716              NaN           NaN         NaN
# RESULTADO_2                NaN        150.84631     71.629484         0.0
# UNIDADES_2              503966              NaN           NaN         NaN
#
#                                25%         50%         75%         max
# FECHA_CORTE             20240531.0  20240531.0  20240531.0  20240531.0
# DEPARTAMENTO                   NaN         NaN         NaN         NaN
# PROVINCIA                      NaN         NaN         NaN         NaN
# DISTRITO                       NaN         NaN         NaN         NaN
# UBIGEO                    110101.0    150101.0    150136.0    250107.0
# RED                            NaN         NaN         NaN         NaN
# IPRESS                         NaN         NaN         NaN         NaN
# ID_PACIENTE                    NaN         NaN         NaN         NaN
# EDAD_PACIENTE                 54.0        63.0        71.0       108.0
# SEXO_PACIENTE                  NaN         NaN         NaN         NaN
# EDAD_MEDICO                   37.0        45.0        55.0        79.0
# ID_MEDICO                      NaN         NaN         NaN         NaN
# COD_DIAG                       NaN         NaN         NaN         NaN
# DIAGNOSTICO                    NaN         NaN         NaN         NaN
# AREA_HOSPITALARIA              NaN         NaN         NaN         NaN
# SERVICIO_HOSPITALARIO          NaN         NaN         NaN         NaN
# ACTIVIDAD_HOSPITALARIA         NaN         NaN         NaN         NaN
# FECHA_MUESTRA           20211229.0  20221125.0  20230822.0  20240430.0
# FEC_RESULTADO_1         20211230.0  20221125.0  20230823.0  20240430.0
# PROCEDIMIENTO_1                NaN         NaN         NaN         NaN
# RESULTADO_1                  159.0       189.0       221.0       963.0
# UNIDADES_1                     NaN         NaN         NaN         NaN
# FEC_RESULTADO_2         20211230.0  20221125.0  20230823.0  20240430.0
# PROCEDIMIENTO_2                NaN         NaN         NaN         NaN
# RESULTADO_2                  104.0       128.0       176.0       989.0
# UNIDADES_2                     NaN         NaN         NaN         NaN

# %%
# Separar los datos segú sus Tipos de variables (numéricas, categóricas). fechas se considera como cat aunque también puedes separr
numeric_data = data.select_dtypes(include=[np.number])
categor_data = data.select_dtypes(exclude=[np.number])
print ("Hay {} variables númericas y {} categóricas en la data".format(numeric_data.shape[1],categor_data.shape[1]))
# Out:
# Hay 9 variables númericas y 17 categóricas en la data

# %%
# Puedes ver la Distribución de variables numéricas
numeric_data.describe().T
# Out:
#                     count          mean           std         min         25%  \
# FECHA_CORTE      509716.0  2.024053e+07      0.000000  20240531.0  20240531.0
# UBIGEO           509716.0  1.309857e+05  55220.281670     10101.0    110101.0
# EDAD_PACIENTE    509716.0  6.186592e+01     13.336874         0.0        54.0
# EDAD_MEDICO      509716.0  4.625489e+01     11.434643        23.0        37.0
# FECHA_MUESTRA    509716.0  2.022329e+07  11218.907109  20200102.0  20211229.0
# FEC_RESULTADO_1  509716.0  2.022331e+07  11218.581031  20200102.0  20211230.0
# RESULTADO_1      509716.0  1.905994e+02     51.550477         0.0       159.0
# FEC_RESULTADO_2  509716.0  2.022331e+07  11219.211046  20200102.0  20211230.0
# RESULTADO_2      509716.0  1.508463e+02     71.629484         0.0       104.0
#
#                         50%         75%         max
# FECHA_CORTE      20240531.0  20240531.0  20240531.0
# UBIGEO             150101.0    150136.0    250107.0
# EDAD_PACIENTE          63.0        71.0       108.0
# EDAD_MEDICO            45.0        55.0        79.0
# FECHA_MUESTRA    20221125.0  20230822.0  20240430.0
# FEC_RESULTADO_1  20221125.0  20230823.0  20240430.0
# RESULTADO_1           189.0       221.0       963.0
# FEC_RESULTADO_2  20221125.0  20230823.0  20240430.0
# RESULTADO_2           128.0       176.0       989.0

# %%
#Variables únicas en cada variable
categor_data.describe(include="all").T
# Out:
#                          count  unique  \
# DEPARTAMENTO            509716      25
# PROVINCIA               509716     111
# DISTRITO                509716     227
# RED                     509716      30
# IPRESS                  509716     272
# ID_PACIENTE             509716  260725
# SEXO_PACIENTE           509716       2
# ID_MEDICO               509716    5290
# COD_DIAG                509716      57
# DIAGNOSTICO             509716      57
# AREA_HOSPITALARIA       509716       1
# SERVICIO_HOSPITALARIO   509716      45
# ACTIVIDAD_HOSPITALARIA  509716      11
# PROCEDIMIENTO_1         509716       1
# UNIDADES_1              509716       2
# PROCEDIMIENTO_2         509716       1
# UNIDADES_2              509716       2
#
#                                                                       top  \
# DEPARTAMENTO                                                         LIMA
# PROVINCIA                                                            LIMA
# DISTRITO                                                             LIMA
# RED                                            RED ASISTENCIAL REBAGLIATI
# IPRESS                                 H.III HOSPITAL DE EMERGENCIAS GRAU
# ID_PACIENTE                          eJwzNDMwsjC2MDQzMTE1NjAwMgUAHuQDaw==
# SEXO_PACIENTE                                                    FEMENINO
# ID_MEDICO                            eJwzNDA1NTWwsDAwNDEwsDQ3MwEAHrkDcA==
# COD_DIAG                                                            E11.9
# DIAGNOSTICO             DIABETES MELLITUS TIPO 2, SIN MENCION DE COMPL...
# AREA_HOSPITALARIA                                        CONSULTA EXTERNA
# SERVICIO_HOSPITALARIO                                    MEDICINA GENERAL
# ACTIVIDAD_HOSPITALARIA                       ATENCION  MEDICA AMBULATORIA
# PROCEDIMIENTO_1         DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...
# UNIDADES_1                                                          mg/dL
# PROCEDIMIENTO_2         DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# UNIDADES_2                                                          mg/dL
#
#                           freq
# DEPARTAMENTO            180751
# PROVINCIA               170963
# DISTRITO                 39651
# RED                      75651
# IPRESS                   21922
# ID_PACIENTE                 21
# SEXO_PACIENTE           297424
# ID_MEDICO                 4934
# COD_DIAG                340278
# DIAGNOSTICO             340278
# AREA_HOSPITALARIA       509716
# SERVICIO_HOSPITALARIO   235494
# ACTIVIDAD_HOSPITALARIA  507211
# PROCEDIMIENTO_1         509716
# UNIDADES_1              503955
# PROCEDIMIENTO_2         509716
# UNIDADES_2              503966

# %%
# Conteo de valores únicos en categóricas (Las posibles importantes)
for col in ['DIAGNOSTICO', 'COD_DIAG', 'AREA_HOSPITALARIA', 'ACTIVIDAD_HOSPITALARIA']:
    print(f"\n{col}:\n", data[col].value_counts())

# Conteo de la variable objetivo
#data["COD_DIAG"].value_counts()
# Out:
# DIAGNOSTICO:
#  DIAGNOSTICO
# DIABETES MELLITUS TIPO 2, SIN MENCION DE COMPLICACION                                        340278
# DIABETES MELLITUS TIPO 2, CON COMPLICACIONES MULTIPLES                                        44702
# DIABETES MELLITUS TIPO 2, CON COMPLICACIONES NO ESPECIFICADAS                                 25176
# OTROS TRASTORNOS ESPECIFICADOS DE LA SECRECION INTERNA DEL PANCREAS                           17316
# DIABETES MELLITUS, NO ESPECIFICADA, SIN MENCION DE COMPLICACION                               12401
# DIABETES MELLITUS TIPO 2, CON COMPLICACIONES NEUROLOGICAS                                      9711
# DIABETES MELLITUS TIPO 1, SIN MENCION DE COMPLICACION                                          9507
# DIABETES MELLITUS ESPECIFICADA, SIN MENCION DE COMPLICACION                                    9248
# TRASTORNOS DE LA SECRECION INTERNA DEL PANCREAS, SIN OTRA ESPECIFICACION                       8123
# DIABETES MELLITUS TIPO 2, CON OTRAS COMPLICACIONES ESPECIFICADAS                               7515
# DIABETES MELLITUS TIPO 2, CON COMPLICACIONES RENALES                                           4565
# DIABETES MELLITUS ESPECIFICADA, CON COMPLICACIONES MULTIPLES                                   3882
# DIABETES MELLITUS TIPO 1, CON COMPLICACIONES MULTIPLES                                         2917
# DIABETES MELLITUS ESPECIFICADA, CON COMPLICACIONES RENALES                                     2769
# DIABETES MELLITUS TIPO 2, CON COMPLICACIONES CIRCULATORIAS PERIFERICAS                         1762
# DIABETES MELLITUS ESPECIFICADA, CON COMPLICACIONES NO ESPECIFICADAS                            1515
# DIABETES MELLITUS ESPECIFICADA, CON COMPLICACIONES NEUROLOGICAS                                1211
# DIABETES MELLITUS TIPO 1, CON COMPLICACIONES NO ESPECIFICADAS                                  1177
# DIABETES MELLITUS TIPO 1, CON COMPLICACIONES NEUROLOGICAS                                       499
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMPLICACIONES NO ESPECIFICADAS                496
# DIABETES MELLITUS TIPO 1, CON OTRAS COMPLICACIONES ESPECIFICADAS                                457
# DIABETES MELLITUS ESPECIFICADA, CON COMPLICACIONES CIRCULATORIAS PERIFERICAS                    454
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMPLICACIONES MULTIPLES                                425
# DIABETES MELLITUS ESPECIFICADA, CON OTRAS COMPLICACIONES ESPECIFICADAS                          352
# DIABETES MELLITUS TIPO 1, CON COMPLICACIONES CIRCULATORIAS PERIFERICAS                          287
# DIABETES MELLITUS TIPO 1, CON COMPLICACIONES RENALES                                            271
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, SIN MENCION DE COMPLICACION                        257
# HIPOGLICEMIA, NO ESPECIFICADA                                                                   256
# DIABETES MELLITUS TIPO 2, CON COMPLICACIONES OFTALMICAS                                         246
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMPLICACIONES MULTIPLES                       241
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMPLICACIONES NO ESPECIFICADAS                         227
# DIABETES MELLITUS, NO ESPECIFICADA, CON OTRAS COMPLICACIONES ESPECIFICADAS                      187
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMPLICACIONES NEUROLOGICAS                             185
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMPLICACIONES RENALES                                  162
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMPLICACIONES NEUROLOGICAS                    152
# DIABETES MELLITUS TIPO 2, CON COMA                                                              141
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMPLICACIONES CIRCULATORIAS PERIFERICAS                100
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMPLICACIONES CIRCULATORIAS PERIFERICAS        75
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMPLICACIONES OFTALMICAS                       54
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON OTRAS COMPLICACIONES ESPECIFICADAS              54
# DIABETES MELLITUS TIPO 2, CON CETOACIDOSIS                                                       54
# DIABETES MELLITUS TIPO 1, CON COMPLICACIONES OFTALMICAS                                          50
# DIABETES MELLITUS ESPECIFICADA, CON COMPLICACIONES OFTALMICAS                                    43
# OTRAS HIPOGLICEMIAS                                                                              42
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMA                                                     30
# HIPOGLICEMIA SIN COMA, INDUCIDA POR DROGAS                                                       28
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMPLICACIONES RENALES                          27
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMPLICACIONES OFTALMICAS                                25
# DIABETES MELLITUS TIPO 1, CON CETOACIDOSIS                                                       15
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON CETOACIDOSIS                                    13
# DIABETES MELLITUS, NO ESPECIFICADA, CON CETOACIDOSIS                                              9
# DIABETES MELLITUS ESPECIFICADA, CON CETOACIDOSIS                                                  9
# DIABETES MELLITUS TIPO 1, CON COMA                                                                6
# SECRECION EXAGERADA DEL GLUCAGON                                                                  5
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMA                                             4
# DIABETES MELLITUS ESPECIFICADA, CON COMA                                                          2
# DIABETES TIPO MODY                                                                                1
# Name: count, dtype: int64
#
# COD_DIAG:
#  COD_DIAG
# E11.9     340278
# E11.7      44702
# E11.8      25176
# E16.8      17316
# E14.9      12401
# E11.4       9711
# E10.9       9507
# E13.9       9248
# E16.9       8123
# E11.6       7515
# E11.2       4565
# E13.7       3882
# E10.7       2917
# E13.2       2769
# E11.5       1762
# E13.8       1515
# E13.4       1211
# E10.8       1177
# E10.4        499
# E12.8        496
# E10.6        457
# E13.5        454
# E14.7        425
# E13.6        352
# E10.5        287
# E10.2        271
# E12.9        257
# E16.2        256
# E11.3        246
# E12.7        241
# E14.8        227
# E14.6        187
# E14.4        185
# E14.2        162
# E12.4        152
# E11.0        141
# E14.5        100
# E12.5         75
# E12.3         54
# E12.6         54
# E11.1         54
# E10.3         50
# E13.3         43
# E16.1         42
# E14.0         30
# E16.0         28
# E12.2         27
# E14.3         25
# E10.1         15
# E12.1         13
# E14.1          9
# E13.1          9
# E10.0          6
# E16.3          5
# E12.0          4
# E13.0          2
# E11.91         1
# Name: count, dtype: int64
#
# AREA_HOSPITALARIA:
#  AREA_HOSPITALARIA
# CONSULTA EXTERNA    509716
# Name: count, dtype: int64
#
# ACTIVIDAD_HOSPITALARIA:
#  ACTIVIDAD_HOSPITALARIA
# ATENCION  MEDICA AMBULATORIA                          507211
# ATENCION AMBULATORIA DESCENTRALIZADA (PAAD)              907
# ATENCION EN MEDICINA COMPLEMENTARIA                      849
# ATENCION EXTRAMURO - REFORMA DE VIDA                     276
# ACTIV.COLECTIVAS  EXTRAMURO (INTERV.EDU.COMUNICAC)       135
# PROGRAMA MI SALUD - MI VIDA EXTRAMUROS                   127
# OTRAS ACTIVIDADES EN HORAS SANITARIAS                    122
# ATENCION EN SALUD OCUPACIONAL                             72
# COPHOES                                                   14
# PAIR                                                       2
# VALORACION DE LA INCAPACIDAD                               1
# Name: count, dtype: int64

# %% [markdown]
# #### 📊 Clasificación de los tipos de diabetes en la data (CIE-10)
#
# La siguiente tabla muestra los códigos **CIE-10** encontrados en la columna `COD_DIAG`, junto con su descripción y la frecuencia de aparición en el dataset:
#
# | Código  | Descripción (CIE-10) | Frecuencia |
# |---------|-----------------------|------------|
# | E11.9   | Diabetes tipo 2 sin complicaciones | 340,278 |
# | E11.7   | Diabetes tipo 2 con complicaciones múltiples | 44,702 |
# | E11.8   | Diabetes tipo 2 con complicaciones no especificadas | 25,176 |
# | E16.8   | Otros trastornos especificados de la secreción pancreática interna | 17,316 |
# | E14.9   | Diabetes mellitus no especificada sin complicaciones | 12,401 |
# | E11.4   | Diabetes tipo 2 con neuropatía | 9,711 |
# | E10.9   | Diabetes tipo 1 sin complicaciones | 9,507 |
# | E13.9   | Otras formas específicas de diabetes mellitus sin complicaciones | 9,248 |
# | E16.9   | Trastorno no especificado de la secreción pancreática interna | 8,123 |
# | E11.6   | Diabetes tipo 2 con pie diabético | 7,515 |
# | E11.2   | Diabetes tipo 2 con enfermedad renal crónica | 4,565 |
# | E13.7   | Otras formas específicas de diabetes con complicaciones múltiples | 3,882 |
# | E10.7   | Diabetes tipo 1 con complicaciones múltiples | 2,917 |
# | E13.2   | Otras formas específicas de diabetes con enfermedad renal crónica | 2,769 |
# | E11.5   | Diabetes tipo 2 con complicaciones circulatorias periféricas | 1,762 |
# | E13.8   | Otras formas específicas de diabetes con complicaciones no especificadas | 1,515 |
# | E13.4   | Otras formas específicas de diabetes con neuropatía | 1,211 |
# | E10.8   | Diabetes tipo 1 con complicaciones no especificadas | 1,177 |
# | E10.4   | Diabetes tipo 1 con neuropatía | 499 |
# | E12.8   | Diabetes debida a desnutrición con complicaciones no especificadas | 496 |
# | E10.6   | Diabetes tipo 1 con pie diabético | 457 |
# | E13.5   | Otras formas específicas de diabetes con complicaciones circulatorias periféricas | 454 |
# | E14.7   | Diabetes no especificada con complicaciones múltiples | 425 |
# | E13.6   | Otras formas específicas de diabetes con pie diabético | 352 |
# | E10.5   | Diabetes tipo 1 con complicaciones circulatorias periféricas | 287 |
# | E10.2   | Diabetes tipo 1 con enfermedad renal crónica | 271 |
# | E12.9   | Diabetes debida a desnutrición sin complicaciones | 257 |
# | E16.2   | Hipoglucemia no especificada | 256 |
# | E11.3   | Diabetes tipo 2 con complicaciones oftálmicas | 246 |
# | E12.7   | Diabetes debida a desnutrición con complicaciones múltiples | 241 |
# | E14.8   | Diabetes no especificada con complicaciones no especificadas | 227 |
# | E14.6   | Diabetes no especificada con pie diabético | 187 |
# | E14.4   | Diabetes no especificada con neuropatía | 185 |
# | E14.2   | Diabetes no especificada con enfermedad renal crónica | 162 |
# | E12.4   | Diabetes debida a desnutrición con neuropatía | 152 |
# | E11.0   | Diabetes tipo 2 con coma | 141 |
# | E14.5   | Diabetes no especificada con complicaciones circulatorias periféricas | 100 |
# | E12.5   | Diabetes debida a desnutrición con complicaciones circulatorias periféricas | 75 |
# | E12.3   | Diabetes debida a desnutrición con complicaciones oftálmicas | 54 |
# | E12.6   | Diabetes debida a desnutrición con pie diabético | 54 |
# | E11.1   | Diabetes tipo 2 con cetoacidosis | 54 |
# | E10.3   | Diabetes tipo 1 con complicaciones oftálmicas | 50 |
# | E13.3   | Otras formas específicas de diabetes con complicaciones oftálmicas | 43 |
# | E16.1   | Hipoglucemia inducida por fármacos | 42 |
# | E14.0   | Diabetes no especificada con coma | 30 |
# | E16.0   | Hipoglucemia inducida por insulina | 28 |
# | E12.2   | Diabetes debida a desnutrición con enfermedad renal crónica | 27 |
# | E14.3   | Diabetes no especificada con complicaciones oftálmicas | 25 |
# | E10.1   | Diabetes tipo 1 con cetoacidosis | 15 |
# | E12.1   | Diabetes debida a desnutrición con cetoacidosis | 13 |
# | E14.1   | Diabetes no especificada con cetoacidosis | 9 |
# | E13.1   | Otras formas específicas de diabetes con cetoacidosis | 9 |
# | E10.0   | Diabetes tipo 1 con coma | 6 |
# | E16.3   | Hipoglucemia posprandial | 5 |
# | E12.0   | Diabetes debida a desnutrición con coma | 4 |
# | E13.0   | Otras formas específicas de diabetes con coma | 2 |
# | E11.91  | Diabetes tipo 2 con complicación no especificada | 1 |
#
# ---
#
# ✅ Esto te permitirá tener una referencia clara de los códigos de diabetes y su significado en tu notebook.

# %% [markdown]
# ### 3.2 Análisis descriptivo (gráficos)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograma de la edad de los pacientes
plt.figure(figsize=(8,5))
sns.histplot(data['EDAD_PACIENTE'], bins=30, kde=True)
plt.title("Distribución de la edad de los pacientes")
plt.xlabel("Edad del paciente")
plt.ylabel("Número de pacientes")
plt.show()

# %% [markdown]
# 👉 El gráfico muestra la distribución de las edades de los pacientes 🧑‍🤝‍🧑📊. La mayoría de los pacientes tienen edades entre 50 y 70 años 🎂, lo que indica que la diabetes es más frecuente en personas adultas y adultas mayores. Se observa un número menor de pacientes jóvenes y niños 👶🧒, mientras que casi no hay casos en edades muy avanzadas (más de 90 años) 👵. En resumen, la enfermedad se concentra sobre todo en la población adulta.

# %%
# Relación entre Edad y Tipo de Diabetes
plt.figure(figsize=(18, 6))  # <-- ajusta ancho y alto
sns.boxplot(x="COD_DIAG", y="EDAD_PACIENTE", data=data)
plt.xlabel("Tipo de diabetes (CIE-10)")
plt.ylabel("Edad de los pacientes")
plt.title("Distribución de la edad según el tipo de diabetes")
plt.xticks(rotation=90)  # <-- rota etiquetas para que no se encimen
plt.show()

# %%
# Distribución de glucosa (RESULTADO_1)
sns.histplot(data['RESULTADO_1'], bins=30, kde=True)
plt.xlabel("Glucosa en sangre mg/dL")
plt.ylabel("Número de pacientes")
plt.title("Distribución de glucosa en sangre")
plt.show()

# %% [markdown]
# El histograma muestra que la mayoría de los pacientes tienen valores de glucosa entre 100 y 250 mg/dL 🩸. Esto es esperado porque los niveles normales rondan los 70–100 mg/dL en ayunas, pero en pacientes con diabetes suelen estar elevados. La gráfica tiene una cola larga hacia la derecha ➡️, lo que indica que existen algunos pacientes con valores mucho más altos (hiperglucemia severa), aunque son casos menos frecuentes.

# %%
# Distribución de colesterol (RESULTADO_2)
sns.histplot(data['RESULTADO_2'], bins=30, kde=True)
plt.xlabel("Colesterol en sangre mg/dL")
plt.ylabel("Número de pacientes")
plt.title("Distribución de colesterol en sangre mg/dL")
plt.show()

# %% [markdown]
# En este caso, la mayoría de los pacientes presentan niveles de colesterol entre 100 y 200 mg/dL 🧪, que es el rango habitual en población general. Al igual que la glucosa, la distribución tiene una cola hacia la derecha ➡️, lo que significa que hay un grupo menor de pacientes con niveles muy altos de colesterol (hipercolesterolemia).

# %% [markdown]
# ### 3.3 Análisis exploratorio (con estadísticas): Correlaciones y cruces de variables

# %%
# Correlaciones de todas las variables númericas
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Matriz de correlaciones de todas las variables númericas")
plt.show()
