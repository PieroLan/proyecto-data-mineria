# %% [markdown]
# # 📌 Fase 1. Business Understanding

# %% [markdown]
# ## 🎯 1. Objective

# %% [markdown]
# El objetivo de este proyecto es **desarrollar un modelo predictivo** que permita determinar el **tipo de diabetes en pacientes** (según el código CIE-10, variable `COD_DIAG`) a partir de características clínicas clave, específicamente:
#
# - **Edad del paciente** (`EDAD_PACIENTE`)
# - **Dosaje de glucosa en sangre, cuantitativo** (`RESULTADO_1`)
# - **Dosaje de colesterol total en sangre** (`RESULTADO_2`)

# %% [markdown]
# # 📌 Fase 2. Data Understanding

# %% [markdown]
# ## 📥 2. Data collection

# %%
import pandas as pd
import numpy as np


data = pd.read_csv("data_diabetes.csv", 
                    encoding='utf-8',      # o 'latin-1' si hay caracteres especiales
                    sep=';',               # separador (por defecto es coma)
                    header=0,              # fila que contiene los nombres de columnas
                    index_col=None)        # si quieres usar una columna como índice

# %%
# Resumen general
data.info()
print('data.columns:',data.columns)
print('data.shape:',data.shape)
data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194585 entries, 0 to 194584
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   FECHA_CORTE             194585 non-null  int64
#  1   DEPARTAMENTO            194585 non-null  object
#  2   PROVINCIA               194585 non-null  object
#  3   DISTRITO                194585 non-null  object
#  4   UBIGEO                  194585 non-null  int64
#  5   RED                     194585 non-null  object
#  6   IPRESS                  194585 non-null  object
#  7   ID_PACIENTE             194585 non-null  object
#  8   EDAD_PACIENTE           194585 non-null  int64
#  9   SEXO_PACIENTE           194585 non-null  object
#  10  EDAD_MEDICO             194585 non-null  int64
#  11  ID_MEDICO               194585 non-null  object
#  12  COD_DIAG                194585 non-null  object
#  13  DIAGNOSTICO             194585 non-null  object
#  14  AREA_HOSPITALARIA       194585 non-null  object
#  15  SERVICIO_HOSPITALARIO   194585 non-null  object
#  16  ACTIVIDAD_HOSPITALARIA  194585 non-null  object
#  17  FECHA_MUESTRA           194584 non-null  float64
#  18  FEC_RESULTADO_1         194584 non-null  float64
#  19  PROCEDIMIENTO_1         194584 non-null  object
#  20  RESULTADO_1             194584 non-null  float64
#  21  UNIDADES_1              194584 non-null  object
#  22  FEC_RESULTADO_2         194584 non-null  float64
#  23  PROCEDIMIENTO_2         194584 non-null  object
#  24  RESULTADO_2             194584 non-null  float64
#  25  UNIDADES_2              194584 non-null  object
# dtypes: float64(5), int64(4), object(17)
# memory usage: 38.6+ MB
# data.columns: Index(['FECHA_CORTE', 'DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'UBIGEO', 'RED',
#        'IPRESS', 'ID_PACIENTE', 'EDAD_PACIENTE', 'SEXO_PACIENTE',
#        'EDAD_MEDICO', 'ID_MEDICO', 'COD_DIAG', 'DIAGNOSTICO',
#        'AREA_HOSPITALARIA', 'SERVICIO_HOSPITALARIO', 'ACTIVIDAD_HOSPITALARIA',
#        'FECHA_MUESTRA', 'FEC_RESULTADO_1', 'PROCEDIMIENTO_1', 'RESULTADO_1',
#        'UNIDADES_1', 'FEC_RESULTADO_2', 'PROCEDIMIENTO_2', 'RESULTADO_2',
#        'UNIDADES_2'],
#       dtype='object')
# data.shape: (194585, 26)
#    FECHA_CORTE DEPARTAMENTO         PROVINCIA      DISTRITO  UBIGEO  \
# 0     20240531      UCAYALI  CORONEL PORTILLO      MANANTAY  250107
# 1     20240531      UCAYALI  CORONEL PORTILLO   YARINACOCHA  250105
# 2     20240531        TACNA             TACNA        CALANA  230103
# 3     20240531        TACNA             TACNA         TACNA  230101
# 4     20240531   SAN MARTIN          HUALLAGA       SAPOSOA  220401
# 5     20240531  LA LIBERTAD          TRUJILLO  LA ESPERANZA  130105
# 6     20240531  LA LIBERTAD          TRUJILLO  LA ESPERANZA  130105
# 7     20240531         LIMA              LIMA    MIRAFLORES  150122
# 8     20240531      HUANUCO           HUANUCO      AMARILIS  100102
# 9     20240531   SAN MARTIN          HUALLAGA       SAPOSOA  220401
#
#                              RED                               IPRESS  \
# 0        RED ASISTENCIAL UCAYALI                       CAP I MANANTAY
# 1        RED ASISTENCIAL UCAYALI                         P.M. ALAMEDA
# 2          RED ASISTENCIAL TACNA         H.III DANIEL ALCIDES CARRION
# 3          RED ASISTENCIAL TACNA  CAP II OSCAR FERNANDEZ DAVILA VELEZ
# 4  MICRORED ASISTENCIAL TARAPOTO                         P.M. SAPOSOA
# 5    RED ASISTENCIAL LA LIBERTAD                     H.I LA ESPERANZA
# 6    RED ASISTENCIAL LA LIBERTAD                     H.I LA ESPERANZA
# 7     RED ASISTENCIAL REBAGLIATI                 H.III SUAREZ-ANGAMOS
# 8        RED ASISTENCIAL HUANUCO                         H.II HUANUCO
# 9  MICRORED ASISTENCIAL TARAPOTO                         P.M. SAPOSOA
#
#                             ID_PACIENTE  EDAD_PACIENTE SEXO_PACIENTE  ...  \
# 0  eJwzNDAwtDC0NDMxNzAyMzWxMAQAHqoDcA==             51     MASCULINO  ...
# 1  eJwzNDAwMjAxNTUxsbQ0NTAzMgUAHnQDbg==             48      FEMENINO  ...
# 2      eJwzNDCwMLOwMDKztDQHsszNAB+JA4w=             67     MASCULINO  ...
# 3  eJwzNDCwNDU3Mja1MDUyMTCxMAEAHukDdA==             67     MASCULINO  ...
# 4      eJwzNDA0szQCQgMDM2NLcxMTAB8CA3k=             59     MASCULINO  ...
# 5  eJwzNLY0tDC1sDQ1NDezNDa0MAEAH8cDiQ==             55     MASCULINO  ...
# 6  eJwzNLY0NjM3NzE2MDE1MTQxNQMAH1MDeQ==             67     MASCULINO  ...
# 7  eJwzNLY0tjQ1NzYwNrU0sLA0MwQAH4gDgg==             73      FEMENINO  ...
# 8  eJwzNDU0NzA0MDc0tzQ2MjM0MgQAHqEDZw==             58      FEMENINO  ...
# 9  eJwzMrUwMjYxsjA3sTA0MDYyMAEAHzcDcA==             20      FEMENINO  ...
#
#          ACTIVIDAD_HOSPITALARIA FECHA_MUESTRA FEC_RESULTADO_1  \
# 0  ATENCION  MEDICA AMBULATORIA    20200102.0      20200111.0
# 1  ATENCION  MEDICA AMBULATORIA    20200102.0      20200111.0
# 2  ATENCION  MEDICA AMBULATORIA    20200102.0      20200102.0
# 3  ATENCION  MEDICA AMBULATORIA    20200102.0      20200102.0
# 4  ATENCION  MEDICA AMBULATORIA    20200102.0      20200102.0
# 5  ATENCION  MEDICA AMBULATORIA    20200102.0      20200102.0
# 6  ATENCION  MEDICA AMBULATORIA    20200102.0      20200102.0
# 7  ATENCION  MEDICA AMBULATORIA    20200102.0      20200102.0
# 8  ATENCION  MEDICA AMBULATORIA    20200102.0      20200106.0
# 9  ATENCION  MEDICA AMBULATORIA    20200102.0      20200102.0
#
#                                      PROCEDIMIENTO_1 RESULTADO_1 UNIDADES_1  \
# 0  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       217.0      mg/dL
# 1  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       192.0      mg/dL
# 2  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       203.0      mg/dL
# 3  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       207.0      mg/dL
# 4  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       155.0      mg/dL
# 5  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...       149.0      mg/dL
# 6  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       221.0      mg/dL
# 7  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       152.0      mg/dL
# 8  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...       221.0      mg/dL
# 9  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...       126.0      mg/dL
#
#   FEC_RESULTADO_2                                    PROCEDIMIENTO_2  \
# 0      20200111.0  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 1      20200111.0  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 2      20200102.0  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 3      20200102.0  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 4      20200102.0  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 5      20200102.0  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...
# 6      20200102.0  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 7      20200102.0  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# 8      20200106.0  DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...
# 9      20200102.0  DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
#
#    RESULTADO_2 UNIDADES_2
# 0        258.0      mg/dL
# 1        171.0      mg/dL
# 2         78.0      mg/dL
# 3        113.0      mg/dL
# 4         78.0      mg/dL
# 5        130.0      mg/dL
# 6        328.0      mg/dL
# 7         83.0      mg/dL
# 8        194.0      mg/dL
# 9         71.0      mg/dL
#
# [10 rows x 26 columns]

# %% [markdown]
# ## 📊 3. Descriptive analysis

# %% [markdown]
# ### 3.1 Análisis descriptivo

# %%
#Resumen estadístico de todas las variables (describe()).
data.describe(include="all").T # incluye categóricas y numéricas
# Out:
#                            count  unique  \
# FECHA_CORTE             194585.0     NaN
# DEPARTAMENTO              194585      25
# PROVINCIA                 194585     101
# DISTRITO                  194585     205
# UBIGEO                  194585.0     NaN
# RED                       194585      30
# IPRESS                    194585     248
# ID_PACIENTE               194585  134430
# EDAD_PACIENTE           194585.0     NaN
# SEXO_PACIENTE             194585       2
# EDAD_MEDICO             194585.0     NaN
# ID_MEDICO                 194585    3594
# COD_DIAG                  194585      55
# DIAGNOSTICO               194585      55
# AREA_HOSPITALARIA         194585       1
# SERVICIO_HOSPITALARIO     194585      39
# ACTIVIDAD_HOSPITALARIA    194585      12
# FECHA_MUESTRA           194584.0     NaN
# FEC_RESULTADO_1         194584.0     NaN
# PROCEDIMIENTO_1           194584       2
# RESULTADO_1             194584.0     NaN
# UNIDADES_1                194584       2
# FEC_RESULTADO_2         194584.0     NaN
# PROCEDIMIENTO_2           194584       2
# RESULTADO_2             194584.0     NaN
# UNIDADES_2                194584       2
#
#                                                                       top  \
# FECHA_CORTE                                                           NaN
# DEPARTAMENTO                                                         LIMA
# PROVINCIA                                                            LIMA
# DISTRITO                                                             LIMA
# UBIGEO                                                                NaN
# RED                                            RED ASISTENCIAL REBAGLIATI
# IPRESS                                 H.III HOSPITAL DE EMERGENCIAS GRAU
# ID_PACIENTE                          eJwzNLE0NTQytTAwtjAxMzY1swQAH0EDgA==
# EDAD_PACIENTE                                                         NaN
# SEXO_PACIENTE                                                    FEMENINO
# EDAD_MEDICO                                                           NaN
# ID_MEDICO                            eJwztLQwNzI3tLAwMDE1tjA0MwQAH8YDgA==
# COD_DIAG                                                            E11.9
# DIAGNOSTICO             DIABETES MELLITUS TIPO 2, SIN MENCION DE COMPL...
# AREA_HOSPITALARIA                                        CONSULTA EXTERNA
# SERVICIO_HOSPITALARIO                                    MEDICINA GENERAL
# ACTIVIDAD_HOSPITALARIA                       ATENCION  MEDICA AMBULATORIA
# FECHA_MUESTRA                                                         NaN
# FEC_RESULTADO_1                                                       NaN
# PROCEDIMIENTO_1         DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# RESULTADO_1                                                           NaN
# UNIDADES_1                                                          mg/dL
# FEC_RESULTADO_2                                                       NaN
# PROCEDIMIENTO_2         DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...
# RESULTADO_2                                                           NaN
# UNIDADES_2                                                          mg/dL
#
#                           freq             mean           std         min  \
# FECHA_CORTE                NaN       20240531.0           0.0  20240531.0
# DEPARTAMENTO             64886              NaN           NaN         NaN
# PROVINCIA                61493              NaN           NaN         NaN
# DISTRITO                 13658              NaN           NaN         NaN
# UBIGEO                     NaN    133928.936167  55798.623896     10101.0
# RED                      27455              NaN           NaN         NaN
# IPRESS                    8233              NaN           NaN         NaN
# ID_PACIENTE                 10              NaN           NaN         NaN
# EDAD_PACIENTE              NaN        61.078639     13.163474         1.0
# SEXO_PACIENTE           112353              NaN           NaN         NaN
# EDAD_MEDICO                NaN        46.539944     11.280245        23.0
# ID_MEDICO                 2107              NaN           NaN         NaN
# COD_DIAG                130968              NaN           NaN         NaN
# DIAGNOSTICO             130968              NaN           NaN         NaN
# AREA_HOSPITALARIA       194585              NaN           NaN         NaN
# SERVICIO_HOSPITALARIO    93303              NaN           NaN         NaN
# ACTIVIDAD_HOSPITALARIA  193735              NaN           NaN         NaN
# FECHA_MUESTRA              NaN  20211873.166843   7250.796699  20200102.0
# FEC_RESULTADO_1            NaN  20211891.971575    7250.23686  20200102.0
# PROCEDIMIENTO_1         106676              NaN           NaN         NaN
# RESULTADO_1                NaN       173.008408     68.607885         0.0
# UNIDADES_1              192476              NaN           NaN         NaN
# FEC_RESULTADO_2            NaN  20211891.929742    7250.14899  20200102.0
# PROCEDIMIENTO_2         106676              NaN           NaN         NaN
# RESULTADO_2                NaN       175.915116     65.528733         0.0
# UNIDADES_2              192481              NaN           NaN         NaN
#
#                                25%         50%         75%         max
# FECHA_CORTE             20240531.0  20240531.0  20240531.0  20240531.0
# DEPARTAMENTO                   NaN         NaN         NaN         NaN
# PROVINCIA                      NaN         NaN         NaN         NaN
# DISTRITO                       NaN         NaN         NaN         NaN
# UBIGEO                    110101.0    150101.0    150141.0    250107.0
# RED                            NaN         NaN         NaN         NaN
# IPRESS                         NaN         NaN         NaN         NaN
# ID_PACIENTE                    NaN         NaN         NaN         NaN
# EDAD_PACIENTE                 54.0        62.0        70.0       108.0
# SEXO_PACIENTE                  NaN         NaN         NaN         NaN
# EDAD_MEDICO                   37.0        45.0        56.0        79.0
# ID_MEDICO                      NaN         NaN         NaN         NaN
# COD_DIAG                       NaN         NaN         NaN         NaN
# DIAGNOSTICO                    NaN         NaN         NaN         NaN
# AREA_HOSPITALARIA              NaN         NaN         NaN         NaN
# SERVICIO_HOSPITALARIO          NaN         NaN         NaN         NaN
# ACTIVIDAD_HOSPITALARIA         NaN         NaN         NaN         NaN
# FECHA_MUESTRA           20210205.0  20210924.0  20220308.0  20220706.0
# FEC_RESULTADO_1         20210208.0  20210924.0  20220308.0  20220922.0
# PROCEDIMIENTO_1                NaN         NaN         NaN         NaN
# RESULTADO_1               120.9175       165.0       213.0       885.0
# UNIDADES_1                     NaN         NaN         NaN         NaN
# FEC_RESULTADO_2         20210208.0  20210924.0  20220308.0  20220922.0
# PROCEDIMIENTO_2                NaN         NaN         NaN         NaN
# RESULTADO_2                  127.1      170.68       214.0       945.0
# UNIDADES_2                     NaN         NaN         NaN         NaN

# %%
# Separar los datos segú sus Tipos de variables (numéricas, categóricas). fechas se considera como cat aunque también puedes separr
numeric_data = data.select_dtypes(include=[np.number])
categor_data = data.select_dtypes(exclude=[np.number])
print ("Hay {} variables númericas y {} categóricas en la data".format(numeric_data.shape[1],categor_data.shape[1]))
# Out:
# Hay 9 variables númericas y 17 categóricas en la data

# %%
# Puedes ver la Distribución de variables numéricas
numeric_data.describe().T
# Out:
#                     count          mean           std         min  \
# FECHA_CORTE      194585.0  2.024053e+07      0.000000  20240531.0
# UBIGEO           194585.0  1.339289e+05  55798.623896     10101.0
# EDAD_PACIENTE    194585.0  6.107864e+01     13.163474         1.0
# EDAD_MEDICO      194585.0  4.653994e+01     11.280245        23.0
# FECHA_MUESTRA    194584.0  2.021187e+07   7250.796699  20200102.0
# FEC_RESULTADO_1  194584.0  2.021189e+07   7250.236860  20200102.0
# RESULTADO_1      194584.0  1.730084e+02     68.607885         0.0
# FEC_RESULTADO_2  194584.0  2.021189e+07   7250.148990  20200102.0
# RESULTADO_2      194584.0  1.759151e+02     65.528733         0.0
#
#                           25%          50%         75%         max
# FECHA_CORTE      2.024053e+07  20240531.00  20240531.0  20240531.0
# UBIGEO           1.101010e+05    150101.00    150141.0    250107.0
# EDAD_PACIENTE    5.400000e+01        62.00        70.0       108.0
# EDAD_MEDICO      3.700000e+01        45.00        56.0        79.0
# FECHA_MUESTRA    2.021020e+07  20210924.00  20220308.0  20220706.0
# FEC_RESULTADO_1  2.021021e+07  20210924.00  20220308.0  20220922.0
# RESULTADO_1      1.209175e+02       165.00       213.0       885.0
# FEC_RESULTADO_2  2.021021e+07  20210924.00  20220308.0  20220922.0
# RESULTADO_2      1.271000e+02       170.68       214.0       945.0

# %%
#Variables únicas en cada variable
categor_data.describe(include="all").T
# Out:
#                          count  unique  \
# DEPARTAMENTO            194585      25
# PROVINCIA               194585     101
# DISTRITO                194585     205
# RED                     194585      30
# IPRESS                  194585     248
# ID_PACIENTE             194585  134430
# SEXO_PACIENTE           194585       2
# ID_MEDICO               194585    3594
# COD_DIAG                194585      55
# DIAGNOSTICO             194585      55
# AREA_HOSPITALARIA       194585       1
# SERVICIO_HOSPITALARIO   194585      39
# ACTIVIDAD_HOSPITALARIA  194585      12
# PROCEDIMIENTO_1         194584       2
# UNIDADES_1              194584       2
# PROCEDIMIENTO_2         194584       2
# UNIDADES_2              194584       2
#
#                                                                       top  \
# DEPARTAMENTO                                                         LIMA
# PROVINCIA                                                            LIMA
# DISTRITO                                                             LIMA
# RED                                            RED ASISTENCIAL REBAGLIATI
# IPRESS                                 H.III HOSPITAL DE EMERGENCIAS GRAU
# ID_PACIENTE                          eJwzNLE0NTQytTAwtjAxMzY1swQAH0EDgA==
# SEXO_PACIENTE                                                    FEMENINO
# ID_MEDICO                            eJwztLQwNzI3tLAwMDE1tjA0MwQAH8YDgA==
# COD_DIAG                                                            E11.9
# DIAGNOSTICO             DIABETES MELLITUS TIPO 2, SIN MENCION DE COMPL...
# AREA_HOSPITALARIA                                        CONSULTA EXTERNA
# SERVICIO_HOSPITALARIO                                    MEDICINA GENERAL
# ACTIVIDAD_HOSPITALARIA                       ATENCION  MEDICA AMBULATORIA
# PROCEDIMIENTO_1         DOSAJE DE GLUCOSA EN SANGRE, CUANTITATIVO (EXC...
# UNIDADES_1                                                          mg/dL
# PROCEDIMIENTO_2         DOSAJE DE COLESTEROL TOTAL EN SANGRE COMPLETA ...
# UNIDADES_2                                                          mg/dL
#
#                           freq
# DEPARTAMENTO             64886
# PROVINCIA                61493
# DISTRITO                 13658
# RED                      27455
# IPRESS                    8233
# ID_PACIENTE                 10
# SEXO_PACIENTE           112353
# ID_MEDICO                 2107
# COD_DIAG                130968
# DIAGNOSTICO             130968
# AREA_HOSPITALARIA       194585
# SERVICIO_HOSPITALARIO    93303
# ACTIVIDAD_HOSPITALARIA  193735
# PROCEDIMIENTO_1         106676
# UNIDADES_1              192476
# PROCEDIMIENTO_2         106676
# UNIDADES_2              192481

# %%
# Conteo de valores únicos en categóricas (Las posibles importantes)
for col in ['DIAGNOSTICO', 'COD_DIAG', 'AREA_HOSPITALARIA', 'ACTIVIDAD_HOSPITALARIA']:
    print(f"\n{col}:\n", data[col].value_counts())

# Conteo de la variable objetivo
#data["COD_DIAG"].value_counts()
# Out:
# DIAGNOSTICO:
#  DIAGNOSTICO
# DIABETES MELLITUS TIPO 2, SIN MENCION DE COMPLICACION                                        130968
# DIABETES MELLITUS TIPO 2, CON COMPLICACIONES MULTIPLES                                        15813
# DIABETES MELLITUS TIPO 2, CON COMPLICACIONES NO ESPECIFICADAS                                  9204
# DIABETES MELLITUS, NO ESPECIFICADA, SIN MENCION DE COMPLICACION                                5934
# OTROS TRASTORNOS ESPECIFICADOS DE LA SECRECION INTERNA DEL PANCREAS                            5589
# DIABETES MELLITUS TIPO 2, CON COMPLICACIONES NEUROLOGICAS                                      5079
# DIABETES MELLITUS TIPO 1, SIN MENCION DE COMPLICACION                                          4527
# TRASTORNOS DE LA SECRECION INTERNA DEL PANCREAS, SIN OTRA ESPECIFICACION                       2680
# DIABETES MELLITUS ESPECIFICADA, SIN MENCION DE COMPLICACION                                    2423
# DIABETES MELLITUS TIPO 2, CON OTRAS COMPLICACIONES ESPECIFICADAS                               2299
# DIABETES MELLITUS ESPECIFICADA, CON COMPLICACIONES MULTIPLES                                   1667
# DIABETES MELLITUS TIPO 2, CON COMPLICACIONES RENALES                                           1624
# DIABETES MELLITUS TIPO 1, CON COMPLICACIONES MULTIPLES                                         1211
# DIABETES MELLITUS ESPECIFICADA, CON COMPLICACIONES RENALES                                      938
# DIABETES MELLITUS TIPO 1, CON COMPLICACIONES NO ESPECIFICADAS                                   536
# DIABETES MELLITUS ESPECIFICADA, CON COMPLICACIONES NO ESPECIFICADAS                             520
# DIABETES MELLITUS TIPO 2, CON COMPLICACIONES CIRCULATORIAS PERIFERICAS                          495
# DIABETES MELLITUS ESPECIFICADA, CON COMPLICACIONES NEUROLOGICAS                                 461
# DIABETES MELLITUS TIPO 1, CON COMPLICACIONES NEUROLOGICAS                                       324
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMPLICACIONES MULTIPLES                                228
# DIABETES MELLITUS ESPECIFICADA, CON OTRAS COMPLICACIONES ESPECIFICADAS                          187
# DIABETES MELLITUS TIPO 1, CON OTRAS COMPLICACIONES ESPECIFICADAS                                174
# DIABETES MELLITUS ESPECIFICADA, CON COMPLICACIONES CIRCULATORIAS PERIFERICAS                    164
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMPLICACIONES NO ESPECIFICADAS                139
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, SIN MENCION DE COMPLICACION                        133
# DIABETES MELLITUS TIPO 1, CON COMPLICACIONES RENALES                                            121
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMPLICACIONES MULTIPLES                       117
# DIABETES MELLITUS TIPO 1, CON COMPLICACIONES CIRCULATORIAS PERIFERICAS                          114
# HIPOGLICEMIA, NO ESPECIFICADA                                                                   111
# DIABETES MELLITUS TIPO 2, CON COMPLICACIONES OFTALMICAS                                         106
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMPLICACIONES NEUROLOGICAS                             106
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMPLICACIONES RENALES                                   61
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMPLICACIONES NEUROLOGICAS                     58
# DIABETES MELLITUS TIPO 2, CON COMA                                                               58
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMPLICACIONES NO ESPECIFICADAS                          58
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMPLICACIONES CIRCULATORIAS PERIFERICAS                 56
# DIABETES MELLITUS, NO ESPECIFICADA, CON OTRAS COMPLICACIONES ESPECIFICADAS                       53
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMPLICACIONES CIRCULATORIAS PERIFERICAS        36
# DIABETES MELLITUS TIPO 1, CON COMPLICACIONES OFTALMICAS                                          32
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON OTRAS COMPLICACIONES ESPECIFICADAS              27
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMPLICACIONES OFTALMICAS                       27
# DIABETES MELLITUS TIPO 2, CON CETOACIDOSIS                                                       25
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMA                                                     20
# HIPOGLICEMIA SIN COMA, INDUCIDA POR DROGAS                                                       17
# DIABETES MELLITUS, NO ESPECIFICADA, CON COMPLICACIONES OFTALMICAS                                14
# DIABETES MELLITUS ESPECIFICADA, CON COMPLICACIONES OFTALMICAS                                    12
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMPLICACIONES RENALES                           8
# OTRAS HIPOGLICEMIAS                                                                               8
# DIABETES MELLITUS TIPO 1, CON CETOACIDOSIS                                                        7
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON CETOACIDOSIS                                     4
# DIABETES MELLITUS TIPO 1, CON COMA                                                                3
# DIABETES MELLITUS ASOCIADA CON DESNUTRICION, CON COMA                                             3
# DIABETES MELLITUS, NO ESPECIFICADA, CON CETOACIDOSIS                                              3
# DIABETES MELLITUS ESPECIFICADA, CON CETOACIDOSIS                                                  2
# SECRECION EXAGERADA DEL GLUCAGON                                                                  1
# Name: count, dtype: int64
#
# COD_DIAG:
#  COD_DIAG
# E11.9    130968
# E11.7     15813
# E11.8      9204
# E14.9      5934
# E16.8      5589
# E11.4      5079
# E10.9      4527
# E16.9      2680
# E13.9      2423
# E11.6      2299
# E13.7      1667
# E11.2      1624
# E10.7      1211
# E13.2       938
# E10.8       536
# E13.8       520
# E11.5       495
# E13.4       461
# E10.4       324
# E14.7       228
# E13.6       187
# E10.6       174
# E13.5       164
# E12.8       139
# E12.9       133
# E10.2       121
# E12.7       117
# E10.5       114
# E16.2       111
# E11.3       106
# E14.4       106
# E14.2        61
# E12.4        58
# E11.0        58
# E14.8        58
# E14.5        56
# E14.6        53
# E12.5        36
# E10.3        32
# E12.6        27
# E12.3        27
# E11.1        25
# E14.0        20
# E16.0        17
# E14.3        14
# E13.3        12
# E12.2         8
# E16.1         8
# E10.1         7
# E12.1         4
# E10.0         3
# E12.0         3
# E14.1         3
# E13.1         2
# E16.3         1
# Name: count, dtype: int64
#
# AREA_HOSPITALARIA:
#  AREA_HOSPITALARIA
# CONSULTA EXTERNA    194585
# Name: count, dtype: int64
#
# ACTIVIDAD_HOSPITALARIA:
#  ACTIVIDAD_HOSPITALARIA
# ATENCION  MEDICA AMBULATORIA                          193735
# ATENCION EN MEDICINA COMPLEMENTARIA                      381
# ATENCION AMBULATORIA DESCENTRALIZADA (PAAD)              310
# ACTIV.COLECTIVAS  EXTRAMURO (INTERV.EDU.COMUNICAC)        54
# ATENCION EN SALUD OCUPACIONAL                             40
# OTRAS ACTIVIDADES EN HORAS SANITARIAS                     28
# ATENCION EXTRAMURO - REFORMA DE VIDA                      14
# PROGRAMA MI SALUD - MI VIDA EXTRAMUROS                    13
# COPHOES                                                    6
# PAIR                                                       2
# VALORACION DE LA INCAPACIDAD                               1
# ATENCION  MEDICA AMBULATORI                                1
# Name: count, dtype: int64

# %% [markdown]
# ### 3.2 Análisis descriptivo (gráficos)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histograma de la edad de los pacientes
plt.figure(figsize=(8,5))
sns.histplot(data['EDAD_PACIENTE'], bins=30, kde=True)
plt.title("Distribución de la edad de los pacientes")
plt.xlabel("Edad del paciente")
plt.ylabel("Número de pacientes")
plt.show()

# %% [markdown]
# 👉 El gráfico muestra la distribución de las edades de los pacientes 🧑‍🤝‍🧑📊. La mayoría de los pacientes tienen edades entre 50 y 70 años 🎂, lo que indica que la diabetes es más frecuente en personas adultas y adultas mayores. Se observa un número menor de pacientes jóvenes y niños 👶🧒, mientras que casi no hay casos en edades muy avanzadas (más de 90 años) 👵. En resumen, la enfermedad se concentra sobre todo en la población adulta.

# %%
# Relación entre Edad y Tipo de Diabetes
sns.boxplot(x="COD_DIAG", y="EDAD_PACIENTE", data=data)
plt.xlabel("Tipo de diabetes (CIE-10)")
plt.ylabel("Edad de los pacientes")
plt.title("Distribución de la edad según el tipo de diabetes")
plt.show()

# %%
# Distribución de glucosa (RESULTADO_1)
sns.histplot(data['RESULTADO_1'], bins=30, kde=True)
plt.xlabel("Glucosa en sangre")
plt.ylabel("Número de pacientes")
plt.title("Distribución de glucosa en sangre")
plt.show()
